# %% [markdown]
# # Exercise description
#
# Based on the conclusions of the previous exercise, in this part we are going to focus on retrieving the list of the first 20 organizations visible on the page. At the end of the script we should get a list with the information about the organization name and its url, according to the example below:
#
# ```python
# [
#  {'name': 'NSPCC',
#   'link': 'https://yougov.co.uk/topics/health/explore/not-for-profit/NSPCC'},
#  {'name': 'Prostate Cancer UK',
#   'link': 'https://yougov.co.uk/topics/health/explore/not-for-profit/Prostate_Cancer_UK'},
#  {'name': 'British Red Cross', ...}
#  ...
# ]
# ```
#
# # List of steps
#
# To complete this exercise you need to do the following:
#
# - import appropriate libraries in the notebook,
# - complete the implementation of the `get_organization_data()` method - this function is going to be responsible for retrieving the data we're interested in from the (single) row corresponding to an organization.
#
# ## Hints:
# - for the page to finish loading you need to **accept** cookies, otherwise it does not fully load,
# - remember to set `implicitly_wait(s)` when going to the page,
# - apart from setting `implicitly_wait` it is also good to add `sleep(1)` from the built-in `time` library before searching for the required page element,
# - remember to close the browser at the end of the script,
# - main page  link:
#
# ```python
# url = 'https://yougov.co.uk/ratings/politics/popularity/charities-organisations/all'
# ```

# %%
from selenium import webdriver
from time import sleep

# Selenium sam pronalazi, preuzima i pokrece odgovarajuci ChromeDriver
browser = webdriver.Chrome()
browser.implicitly_wait(10)

# %%
url = 'https://yougov.com/en-gb/ratings/charities-organisations'
browser.get(url)

# %%
sleep(1)
cookies_btn = browser.find_element('id', 'onetrust-accept-btn-handler')
cookies_btn.click()

# %%
orgs_container = browser.find_element('css selector', '.rankings-entities-list')
orgs = orgs_container.find_elements("tag name", 'li')
orgs
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.267")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.268")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.269")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.270")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.271")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.272")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.273")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.274")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.275")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.276")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.277")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.278")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.279")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.280")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.281")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.282")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.283")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.284")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.285")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6f3aa710419351865ecf778642a91b7a", element="f.6C7AFFC13505C05E31E94583E020F95F.d.36563A9CD87CA899EB77A47243CAABA0.e.286")>]

# %%
# complete here
def get_organization_data(org):
    results =[]

    for o in orgs:
        name = o.find_elements('tag name', 'span')[2].text
        link = o.find_element('tag name', 'a').get_attribute('href')

        record = {
            'name':name,
            'link':link
        }

        results.append(record)

    return results
results = get_organization_data(orgs)
results
# Out:
# [{'name': 'Marie Curie',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Marie_Curie'},
#  {'name': 'Macmillan Cancer Support',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Macmillan_Cancer_Support'},
#  {'name': 'St. John Ambulance',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/St_John_Ambulance'},
#  {'name': 'Cancer Research UK',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Cancer_Research_UK'},
#  {'name': 'Guide Dogs',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Guide_Dogs'},
#  {'name': 'British Heart Foundation',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/British_Heart_Foundation'},
#  {'name': 'Samaritans',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Samaritans'},
#  {'name': "Alzheimer's Research UK",
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Alzheimers_Research_UK'},
#  {'name': "Alzheimer's Society",
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Alzheimers_Society'},
#  {'name': 'ChildLine',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/ChildLine'},
#  {'name': 'Great Ormond Street Hospital',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Great_Ormond_Street_Hospital'},
#  {'name': 'RSPCA',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/RSPCA'},
#  {'name': 'Mind',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Mind'},
#  {'name': 'British Red Cross',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/British_Red_Cross'},
#  {'name': 'National Trust',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/National_Trust'},
#  {'name': 'Prostate Cancer UK',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Prostate_Cancer_UK'},
#  {'name': 'WWF', 'link': 'https://yougov.com/en-gb/topics/not-for-profit/WWF'},
#  {'name': 'Dogs Trust',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Dogs_Trust'},
#  {'name': 'Royal British Legion',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Royal_British_Legion'},
#  {'name': 'Keep Britain Tidy',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Keep_Britain_Tidy'}]

# %%
browser.quit()
