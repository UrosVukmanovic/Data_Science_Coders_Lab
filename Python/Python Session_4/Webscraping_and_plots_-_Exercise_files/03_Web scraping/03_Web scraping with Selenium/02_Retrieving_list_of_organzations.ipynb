# %% [markdown]
# # Exercise description
#
# Based on the conclusions of the previous exercise, in this part we are going to focus on retrieving the list of the first 20 organizations visible on the page. At the end of the script we should get a list with the information about the organization name and its url, according to the example below:
#
# ```python
# [
#  {'name': 'NSPCC',
#   'link': 'https://yougov.co.uk/topics/health/explore/not-for-profit/NSPCC'},
#  {'name': 'Prostate Cancer UK',
#   'link': 'https://yougov.co.uk/topics/health/explore/not-for-profit/Prostate_Cancer_UK'},
#  {'name': 'British Red Cross', ...}
#  ...
# ]
# ```
#
# # List of steps
#
# To complete this exercise you need to do the following:
#
# - import appropriate libraries in the notebook,
# - complete the implementation of the `get_organization_data()` method - this function is going to be responsible for retrieving the data we're interested in from the (single) row corresponding to an organization.
#
# ## Hints:
# - for the page to finish loading you need to **accept** cookies, otherwise it does not fully load,
# - remember to set `implicitly_wait(s)` when going to the page,
# - apart from setting `implicitly_wait` it is also good to add `sleep(1)` from the built-in `time` library before searching for the required page element,
# - remember to close the browser at the end of the script,
# - main page  link:
#
# ```python
# url = 'https://yougov.co.uk/ratings/politics/popularity/charities-organisations/all'
# ```

# %%
from selenium import webdriver
browser = webdriver.Chrome()

# %%
browser.implicitly_wait(10)
url = 'https://yougov.com/en-gb/ratings/charities-organisations'
browser.get(url)

# %%
orgs_container = browser.find_element('css selector', '.rankings-entities-list')
orgs = orgs_container.find_elements("tag name", 'li')
orgs
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.40")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.43")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.47")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7adaa1dab9ec759770d8fb6d93a73193", element="f.E81C6D350622552A2ABAE23C0757C7B5.d.403681C0133E65250915BA08D18E6CBE.e.50")>]

# %%
results =[]

for o in orgs:
    name = o.find_elements('tag name', 'span')[2].text
    link = o.find_element('tag name', 'a').get_attribute('href')

    record = {
        'name':name,
        'link':link
    }

    results.append(record)

results
# Out:
# [{'name': 'Macmillan Cancer Support',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Macmillan_Cancer_Support'},
#  {'name': 'Cancer Research UK',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Cancer_Research_UK'},
#  {'name': 'St. John Ambulance',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/St_John_Ambulance'},
#  {'name': 'British Heart Foundation',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/British_Heart_Foundation'},
#  {'name': 'Samaritans',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Samaritans'},
#  {'name': 'Prostate Cancer UK',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Prostate_Cancer_UK'},
#  {'name': 'RNLI Lifeboats',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/RNLI_Lifeboats'},
#  {'name': 'WWF', 'link': 'https://yougov.com/en-gb/topics/not-for-profit/WWF'},
#  {'name': 'Great Ormond Street Hospital',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Great_Ormond_Street_Hospital'},
#  {'name': "Alzheimer's Society",
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Alzheimers_Society'},
#  {'name': 'RSPCA',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/RSPCA'},
#  {'name': 'Guide Dogs',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Guide_Dogs'},
#  {'name': "Alzheimer's Research UK",
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Alzheimers_Research_UK'},
#  {'name': 'Prostate Cancer Research',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Prostate_Cancer_Research'},
#  {'name': 'Dementia UK',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Dementia_UK'},
#  {'name': 'Marie Curie',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Marie_Curie'},
#  {'name': 'Royal British Legion',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Royal_British_Legion'},
#  {'name': 'National Trust',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/National_Trust'},
#  {'name': 'Dogs Trust',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Dogs_Trust'},
#  {'name': 'Age UK',
#   'link': 'https://yougov.com/en-gb/topics/not-for-profit/Age_UK'}]

# %%
# complete here
def get_organization_data(org):
    pass

# %%
# launch the browser here but do not open the website yet; remember to add `implicitly_wait`!
