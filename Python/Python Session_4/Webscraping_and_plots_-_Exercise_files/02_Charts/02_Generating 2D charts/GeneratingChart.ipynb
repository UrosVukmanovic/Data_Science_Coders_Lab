# %%
import pandas as pd
df = pd.read_csv('Meteo data.csv', sep=';', decimal='.')
df
# Out:
#      Station code       Station name  Year  Month  Day  \
# 0        252200150  WARSZAWA-BIELANY  2020      1    1
# 1        252200150  WARSZAWA-BIELANY  2020      1    2
# 2        252200150  WARSZAWA-BIELANY  2020      1    3
# 3        252200150  WARSZAWA-BIELANY  2020      1    4
# 4        252200150  WARSZAWA-BIELANY  2020      1    5
# ..             ...               ...   ...    ...  ...
# 361      252200150  WARSZAWA-BIELANY  2020     12   27
# 362      252200150  WARSZAWA-BIELANY  2020     12   28
# 363      252200150  WARSZAWA-BIELANY  2020     12   29
# 364      252200150  WARSZAWA-BIELANY  2020     12   30
# 365      252200150  WARSZAWA-BIELANY  2020     12   31
#
#      Average daily temperature  Average daily relative humidity  \
# 0                          2.4                             89.5
# 1                          1.3                             77.5
# 2                          2.3                             75.3
# 3                          3.3                             84.0
# 4                          0.7                             79.5
# ..                         ...                              ...
# 361                       -0.8                             76.3
# 362                        4.0                             82.0
# 363                        6.0                             79.3
# 364                        4.4                             92.5
# 365                        1.4                             99.5
#
#      Average daily wind speed [m/s]  Average daily cloud cover [oktas]
# 0                               5.0                                8.0
# 1                               3.3                                7.0
# 2                               3.7                                5.3
# 3                               5.0                                6.7
# 4                               3.3                                0.7
# ..                              ...                                ...
# 361                             5.0                                1.0
# 362                             5.7                                7.3
# 363                             3.7                                5.3
# 364                             1.3                                8.0
# 365                             1.3                                8.0
#
# [366 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Station code ', 'Station name', 'Year', 'Month', 'Day',
#        'Average daily temperature', 'Average daily relative humidity',
#        'Average daily wind speed [m/s]', 'Average daily cloud cover [oktas]'],
#       dtype='object')

# %%
# A list containing the starting days for the months
months_change = [0, 31, 60, 91, 121, 152, 182, 213, 244, 274, 305, 335]
# A list containing the names of the months
months_names = ['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December']
# Dataset containing 12 values: average for monthly measurements
df_month_avg = df.groupby('Month')[[
        'Average daily temperature', 'Average daily relative humidity',
        'Average daily wind speed [m/s]', 'Average daily cloud cover [oktas]'
]].mean()
 
df_month_avg.columns = [
        'Average temperature', 'Average relative humidity',
        'Average wind speed [m/s]', 'Average total cloud cover [oktas]'
]
df_month_avg
# Out:
#        Average temperature  Average relative humidity  \
# Month
# 1                 2.890323                  84.838710
# 2                 4.293103                  78.124138
# 3                 5.067742                  61.983871
# 4                 9.570000                  50.206667
# 5                12.109677                  65.329032
# 6                19.093333                  75.943333
# 7                19.635484                  68.054839
# 8                20.170968                  69.087097
# 9                15.543333                  77.610000
# 10               10.774194                  86.732258
# 11                6.073333                  88.046667
# 12                2.338710                  87.896774
#
#        Average wind speed [m/s]  Average total cloud cover [oktas]
# Month
# 1                      3.374194                           6.145161
# 2                      3.417241                           5.606897
# 3                      2.967742                           4.503226
# 4                      2.870000                           2.953333
# 5                      2.580645                           4.912903
# 6                      2.196667                           5.073333
# 7                      2.225806                           4.283871
# 8                      1.912903                           3.948387
# 9                      2.173333                           3.860000
# 10                     2.345161                           5.845161
# 11                     2.416667                           6.180000
# 12                     3.554839                           6.606452

# %%
import matplotlib.pyplot as plt
 
plt.figure(figsize=(15,10))
plt.plot(df['Average daily temperature'], label='Daily temperature')
plt.plot(months_change, df_month_avg['Average temperature'], '-.r', label='Average temperature', drawstyle='steps-post')
plt.xticks(ticks=months_change, labels=months_names, rotation=45)
plt.ylabel('Temperature (c)')
plt.xlabel('Months')
plt.title("Temperature in Poland in 2020")
plt.legend()
plt.grid()
plt.savefig('chart_A.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4]
y = [2, 5, 1, 7]

# Option 1: Using plt.step()
plt.step(x, y, where='pre', label='pre')
plt.step(x, y, where='mid', label='mid')
plt.step(x, y, where='post', label='post')

# Option 2: Using plt.plot() with drawstyle
plt.plot(x, y, drawstyle='steps-pre')
plt.show()
plt.plot(x, y, drawstyle='steps-pre')
plt.show()
plt.plot(x, y, drawstyle='steps-post')  
plt.show()

# %%
# simple line plot - we only pass the parameter with y-axis values
plt.plot([1,2,2,1])
# diamond shape - we pass 2 lists that specify the x and y coordinates for each point
plt.plot([-1, -0.5 , 0.5, 1, 0, -1], [2, 3, 3, 2, 0, 2])

# %%
plt.plot([1,2,3,2], '* b') # blue stars not connected by a line

# %%
plt.plot([1,2,3,2], '>-.y') # yellow triangles (pointing right) connected with a dash-dot line

# %%
plt.plot([0,1.4,1.8,2.7], '-.y')
#plt.plot([0,1.4,1.8,2.7], '*-.y') # dodatno zvezdica na krajevima
plt.xticks(ticks=[0, 1.5, 2],
           labels=['Test start', 'Phase 2', 'Phase 3'])
plt.yticks(ticks=[2],
           labels=['Tolerance limit'])
# Out:
# ([<matplotlib.axis.YTick at 0x1cde5793350>], [Text(0, 2, 'Tolerance limit')])

# %%
plt.plot([0,1,3,2], '-.y')
plt.ylabel(ylabel='Stress (in pascals)', loc='bottom')
plt.xlabel(xlabel='Time (in seconds)', loc='right')
# Out:
# Text(1, 0, 'Time (in seconds)')

# %%
plt.plot([0,1,3,2], '-.y')
plt.title('Plot 1.1')
# Out:
# Text(0.5, 1.0, 'Plot 1.1')

# %%
plt.plot([0,1,3,2], '-.y', label='Plot A')
plt.plot([2,5,1,3], '-g', label='Plot B')
plt.plot([3,1,4,2], '--k', label='Plot c')
plt.legend()

# %%
plt.plot([0,1,3,2])
plt.grid()

# %%
plt.plot([0,1,3,2])
plt.minorticks_on() 
plt.grid(which='both')

# %%
plt.plot([0,1,3,2])
plt.minorticks_on() 
plt.grid(axis='y', which='major', color='r', linestyle='-')

# %%
plt.plot([0,1,3,2])
plt.grid(which='major', color='r', linestyle='-')

# %%
plt.plot([0,1,3,2])
plt.show()
plt.plot([0,1,3,2])
plt.show()

# %%
a = [
    (0.0, -1.0),
    (-1.176, -1.618),
    (-0.951, -0.309),
    (-1.902, 0.618),
    (-0.588, 0.809),
    (-0.0, 2.0),
    (0.588, 0.809),
    (1.902, 0.618),
    (0.951, -0.309),
    (1.176, -1.618)
]

# %%
x, y = zip(*a)
x, y
# Out:
# ((0.0, -1.176, -0.951, -1.902, -0.588, -0.0, 0.588, 1.902, 0.951, 1.176),
#  (-1.0, -1.618, -0.309, 0.618, 0.809, 2.0, 0.809, 0.618, -0.309, -1.618))

# %%
x= [point[0] for point in a]
y= [point[1] for point in a]
x,y
# Out:
# ([0.0, -1.176, -0.951, -1.902, -0.588, -0.0, 0.588, 1.902, 0.951, 1.176],
#  [-1.0, -1.618, -0.309, 0.618, 0.809, 2.0, 0.809, 0.618, -0.309, -1.618])

# %%
plt.plot(x,y)

# %%
x.append(x[0])
y.append(y[0])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, '-.r')

# %%
plt.plot(x,y, '-.r', linewidth=2, markersize=10, label='Plot A')
plt.legend()
plt.show()

# %%
import pandas as pd
df = pd.read_csv('Meteo data.csv', sep=';', decimal='.')
df
# Out:
#      Station code       Station name  Year  Month  Day  \
# 0        252200150  WARSZAWA-BIELANY  2020      1    1
# 1        252200150  WARSZAWA-BIELANY  2020      1    2
# 2        252200150  WARSZAWA-BIELANY  2020      1    3
# 3        252200150  WARSZAWA-BIELANY  2020      1    4
# 4        252200150  WARSZAWA-BIELANY  2020      1    5
# ..             ...               ...   ...    ...  ...
# 361      252200150  WARSZAWA-BIELANY  2020     12   27
# 362      252200150  WARSZAWA-BIELANY  2020     12   28
# 363      252200150  WARSZAWA-BIELANY  2020     12   29
# 364      252200150  WARSZAWA-BIELANY  2020     12   30
# 365      252200150  WARSZAWA-BIELANY  2020     12   31
#
#      Average daily temperature  Average daily relative humidity  \
# 0                          2.4                             89.5
# 1                          1.3                             77.5
# 2                          2.3                             75.3
# 3                          3.3                             84.0
# 4                          0.7                             79.5
# ..                         ...                              ...
# 361                       -0.8                             76.3
# 362                        4.0                             82.0
# 363                        6.0                             79.3
# 364                        4.4                             92.5
# 365                        1.4                             99.5
#
#      Average daily wind speed [m/s]  Average daily cloud cover [oktas]
# 0                               5.0                                8.0
# 1                               3.3                                7.0
# 2                               3.7                                5.3
# 3                               5.0                                6.7
# 4                               3.3                                0.7
# ..                              ...                                ...
# 361                             5.0                                1.0
# 362                             5.7                                7.3
# 363                             3.7                                5.3
# 364                             1.3                                8.0
# 365                             1.3                                8.0
#
# [366 rows x 9 columns]

# %%
# A list containing the starting days for the months
months_change = [0, 31, 60, 91, 121, 152, 182, 213, 244, 274, 305, 335]

# A list containing the names of the months
months_names = ['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December']
# Dataset containing 12 values: average for monthly measurements
df_daily_avg = df[['Average daily relative humidity']]
 
df_daily_avg.columns = [
        'Average daily relative humidity'
]
df_daily_avg
# Out:
#      Average daily relative humidity
# 0                               89.5
# 1                               77.5
# 2                               75.3
# 3                               84.0
# 4                               79.5
# ..                               ...
# 361                             76.3
# 362                             82.0
# 363                             79.3
# 364                             92.5
# 365                             99.5
#
# [366 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.plot(df_daily_avg.index, df_daily_avg['Average daily relative humidity'], '-.r', label='Average daily relative humidity', drawstyle='steps-post')
plt.xticks(ticks=months_change, labels=months_names, rotation=45)
plt.ylabel('Relative Humidity (%)')
plt.xlabel('Months')
plt.title("Relative Humidity in Poland in 2020")
plt.legend()
plt.grid()
plt.savefig('chart_A.jpg')
plt.show()
