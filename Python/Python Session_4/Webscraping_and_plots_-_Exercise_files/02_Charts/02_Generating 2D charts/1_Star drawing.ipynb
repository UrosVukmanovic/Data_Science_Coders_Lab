# %% [markdown]
# The following list contains the coordinates (x, y) of the vertices of a five-pointed star. Display such a star on a Matplotlib chart.
#
# Notice that the `.plot(...)` method needs data in the form of two separate lists: one with X and other with Y coordinates. You need to prepare such lists from the `points` list.
#
# The star based only on these vertices will not have a single edge - correct this.

# %%
lista_full = [
    (0.0, -1.0),
    (-1.176, -1.618),
    (-0.951, -0.309),
    (-1.902, 0.618),
    (-0.588, 0.809),
    (-0.0, 2.0),
    (0.588, 0.809),
    (1.902, 0.618),
    (0.951, -0.309),
    (1.176, -1.618),
    (0.0, -1.0)
]

# %%
x,y = zip(*lista_full)

x,y
# Out:
# ((0.0, -1.176, -0.951, -1.902, -0.588, -0.0, 0.588, 1.902, 0.951, 1.176, -1.0),
#  (-1.0, -1.618, -0.309, 0.618, 0.809, 2.0, 0.809, 0.618, -0.309, -1.618, 0))

# %%
x = [point[0] for point in lista_full]
y = [point[1] for point in lista_full]

x, y
# Out:
# ([0.0, -1.176, -0.951, -1.902, -0.588, -0.0, 0.588, 1.902, 0.951, 1.176, 0.0],
#  [-1.0, -1.618, -0.309, 0.618, 0.809, 2.0, 0.809, 0.618, -0.309, -1.618, -1.0])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.plot (x, y, '-*')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
