# %% [markdown]
# # Grouping data across sheets
#
# Modify the previous exercise so that each product group is in a separate worksheet together with the corresponding `product_group_id`. For example
# `product_group_id` 1 should go to the sheet named `1`.
#
# Use the method to create a new workbook:
# ```
# wb.create_sheet(name, index)
# ```
# Where:
# - `name` - is the name of the workbook, where we want to save the data (should be a string),
# - `index` - is the worksheet position in the workbook.

# %%
import pandas as pd
import openpyxl
from openpyxl.utils.dataframe import dataframe_to_rows

df = pd.read_csv(
    r'C:\Users\UrosVukmanovic\CodersLab-Course-Python-Data-Analysis\Python Session_3\Session_3_-_exercise_files\01_Data\product_prices_cleaned_2.csv',
    sep=';',
    encoding='UTF-8',
    decimal='.'
)

# %%
wb = openpyxl.Workbook()
ws = wb.active

# %%
df.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN               2.0
# 1               ŁÓDŹ           NaN      PLN               4.0
# 2  KUYAVIA-POMERANIA           NaN      PLN               2.0
# 3      LOWER SILESIA           NaN      PLN               2.0
# 4     WARMIA-MASURIA           NaN      PLN               2.0
#
#                       product_line  value        date  \
# 0        pork ham cooked - per 1kg  21.37  2013-03-01
# 1                  bread - per 1kg    NaN  2018-02-01
# 2  barley groats sausage - per 1kg   3.55  2019-12-01
# 3       dressed chickens - per 1kg   6.14  2019-02-01
# 4    Italian head cheese - per 1kg   5.63  2002-03-01
#
#                            product  month    year  quarter
# 0        pork ham cooked - per 1kg    3.0  2013.0      1.0
# 1                  bread - per 1kg    2.0  2018.0      1.0
# 2  barley groats sausage - per 1kg   12.0  2019.0      4.0
# ...

# %%
# Poenta zadatka je da napravimo novi sheet za svaki product_group_id(ima ih 4) i da u svakom sheetu ispisemo df podatke vezane samo za taj product id

df_by_id = df.groupby(by=['product_group_id']) # pravimo grupisani iterabilni objekat
df_by_id.head()

i=0
for (id, _df) in df_by_id: # zadajemo da nam je kljuc taj id iz group by(sam se pravi) ostatak je ostatak df
    print('id')
    print(id)
    ws = wb.create_sheet(str(id), i) # otvaramo sheet prvo za id 1 pa za id 2 u drugom prolazu itd
    for r in dataframe_to_rows(_df, index=False, header=True): # za id 1 ispisujemo sve podatke pomocu dataframe_to_row metode u taj sheet
        ws.append(r) # upisujemo podatke # upisujemo izvojene podatke
    i+=1 # zatvara se prvi sheet brojac se povecava da bi otvorio sheet 2 
wb.save(r'C:\Users\UrosVukmanovic\CodersLab-Course-Python-Data-Analysis\Python Session_3\Session_3_-_exercise_files\01_Data\product_prices_cleaned_grouped.xlsx') # cuvamo podatke
# Out:
# id
# (1.0,)
# id
# (2.0,)
# id
# (3.0,)
# id
# (4.0,)

# %%
df_by_id = df.groupby(by=['product_group_id'])
df_by_id.head()

i = 0
for (id, _df) in df_by_id:
    print("id", id)
    print("_df", _df)
# Out:
# id (1.0,)
# _df                  province                            product_types currency  \
# 5              HOLY CROSS  whole pickled cucumbers 0.9l - per 1pc.      PLN
# 12              POMERANIA         30% tomato concentrate - per 1kg      PLN
# 15                 POLAND  whole pickled cucumbers 0.9l - per 1pc.      PLN
# 26          LOWER SILESIA      frozen carrot and pea mix - per 1kg      EUR
# 37                MASOVIA              apple juice, boxed - per 1l      PLN
# ...                   ...                                      ...      ...
# 132181            SILESIA      frozen carrot and pea mix - per 1kg      EUR
# 132185     GREATER POLAND              apple juice, boxed - per 1l      PLN
# 132195         HOLY CROSS      frozen carrot and pea mix - per 1kg      EUR
# 132201  KUYAVIA-POMERANIA  whole pickled cucumbers 0.9l - per 1pc.      PLN
# 132204         HOLY CROSS  whole pickled cucumbers 0.9l - per 1pc.      PLN
#
# ...
