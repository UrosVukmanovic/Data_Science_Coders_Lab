# %% [markdown]
# # Exercise 1
#
# Get familiar with the [/weather endpoint documentation](https://openweathermap.org/current#name).
#
# Write a `get_weather` function that takes three arguments:
# - `city` - name of the city, **required**,
# - `state` - name of the state/province, optional,
# - `country` - name of the country, optional.
#
# In the function use the API [https://openweathermap.org](openweathermap.org) to check current weather. Use all available information (`city`, `state`, `country`) in the request in such a way that the function still works if only `city` or `city` and `country` is passed.
#
# The function should return a short name of the weather: `"Clouds"`, `"Rain"`, `"Clear"` - read it from the JSON returned by the server.
#
# Remember to pass `appid`.

# %%
import json
import requests

city_name = input(str("enter city name:\t"))
state_name = input(str("enter state name:\t"))
country_name = input(str("enter country name:\t"))


def get_weather(city, state=None, country=None):
    url = f'https://api.openweathermap.org/data/2.5/weather?q={city},{state},{country}&appid={"8e6e534cbed6c3b7db7eb79eb25ae299"}'
    response = requests.get(url)
    data = response.json()
    weather = data["weather"][0]
    print(data)
    weather_descr = weather["main"]
    return weather_descr


print(f'Weather for {city_name}, {get_weather(city_name, state_name, country_name)}')
print(f'{city_name} once again:, {get_weather(city_name)}')
# Out:
# {'coord': {'lon': -84.1986, 'lat': 34.0289}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 294.72, 'feels_like': 295.39, 'temp_min': 293.57, 'temp_max': 295.24, 'pressure': 1016, 'humidity': 94, 'sea_level': 1016, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 265, 'gust': 1.34}, 'clouds': {'all': 94}, 'dt': 1780054118, 'sys': {'type': 2, 'id': 2038353, 'country': 'US', 'sunrise': 1780050464, 'sunset': 1780101662}, 'timezone': -14400, 'id': 6331909, 'name': 'Johns Creek', 'cod': 200}
# Weather for Johns Creek, Clouds
# {'coord': {'lon': -84.1902, 'lat': 34.0182}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 294.77, 'feels_like': 295.44, 'temp_min': 293.59, 'temp_max': 295.27, 'pressure': 1016, 'humidity': 94, 'sea_level': 1016, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 265, 'gust': 1.34}, 'clouds': {'all': 95}, 'dt': 1780054118, 'sys': {'type': 2, 'id': 76091, 'country': 'US', 'sunrise': 1780050463, 'sunset': 1780101659}, 'timezone': -14400, 'id': 6331909, 'name': 'Johns Creek', 'cod': 200}
# Johns Creek once again:, Clouds
